# %% [markdown]
# ## Set Up

# %%
import os
import json
import numpy
import datetime
import certifi
import pandas as pd
import pymysql

import pymongo
import sqlalchemy
from sqlalchemy import create_engine, text
from pymongo import MongoClient

# %%
mysql_args = {
    "uid" : "root",
    "pwd" : "tpwk",
    "hostname" : "localhost",
    "dbname" : "adventureworks"
}

# The 'cluster_location' must either be "atlas" or "local".
mongodb_args = {
    "user_name" : "lcliau18_db_user",
    "password" : "tpwk",
    "cluster_name" : "cluster0",
    "cluster_subnet" : "ep8zqil",
    "cluster_location" : "atlas", # "local"
    "db_name" : "adventureworks"
}

# %%
def get_sql_dataframe(sql_query, **args):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{args['uid']}:{args['pwd']}@{args['hostname']}/{args['dbname']}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    '''Invoke the pd.read_sql() function to query the database, and fill a Pandas DataFrame.'''
    dframe = pd.read_sql(text(sql_query), connection);
    connection.close()
    
    return dframe
    

def set_dataframe(df, table_name, pk_column, db_operation, **args):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{args['uid']}:{args['pwd']}@{args['hostname']}/{args['dbname']}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    '''Invoke the Pandas DataFrame .to_sql( ) function to either create, or append to, a table'''
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        connection.execute(text(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});"))
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()


def get_mongo_client(**args):
    '''Validate proper input'''
    if args["cluster_location"] not in ['atlas', 'local']:
        raise Exception("You must specify either 'atlas' or 'local' for the cluster_location parameter.")
    
    else:
        if args["cluster_location"] == "atlas":
            connect_str = f"mongodb+srv://{args['user_name']}:{args['password']}@"
            connect_str += f"{args['cluster_name']}.{args['cluster_subnet']}.mongodb.net"
            client = pymongo.MongoClient(connect_str, tlsCAFile=certifi.where())
            
        elif args["cluster_location"] == "local":
            client = pymongo.MongoClient("mongodb://localhost:27017/")
        
    return client


def get_mongo_dataframe(mongo_client, db_name, collection, query):
    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = mongo_client[db_name]
    dframe = pd.DataFrame(list(db[collection].find(query)))
    dframe.drop(['_id'], axis=1, inplace=True)
    mongo_client.close()
    
    return dframe


def set_mongo_collections(mongo_client, db_name, data_directory, json_files):
    db = mongo_client[db_name]
    
    for file in json_files:
        db.drop_collection(file)
        json_file = os.path.join(data_directory, json_files[file])
        with open(json_file, 'r') as openfile:
            json_object = json.load(openfile)
            file = db[file]
            result = file.insert_many(json_object)
        
    mongo_client.close()

# %% [markdown]
# ## Populate MongoDB with Source Data

# %%
client = get_mongo_client(**mongodb_args)

data_dir = os.path.join(os.getcwd(), 'data')

json_files = {"customers" : 'customers.json',
              "employees" : 'employees.json',
              "vendors" : 'vendors.json',
              "products" : 'products.json',
              "fact_purchase_orders" : 'fact_purchase_orders.json',
              "fact_sales_orders" : 'fact_sales_orders.json'
             }

set_mongo_collections(client, mongodb_args["db_name"], data_dir, json_files)

# %% [markdown]
# ## Creating and Populating the New Dimension Tables

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "customers"
df_dim_customers = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_dim_customers.head(2)
# Out:
#    CustomerID AccountNumber CustomerType  AddressType        AddressLine1  \
# 0           1    AW00000001            S  Main Office  2251 Elliot Avenue
# 1           2    AW00000002            S     Shipping     7943 Walnut Ave
#
#   AddressLine2     City StateProvinceCode State_Province  \
# 0         None  Seattle               WA      Washington
# 1         None   Renton               WA      Washington
#
#   IsOnlyStateProvinceFlag PostalCode CountryRegionCode Country_Region  \
# 0                       0      98104                US  United States
# 1                       0      98055                US  United States
#
#   Sales Territory Group Sales Territory
# 0         North America       Northwest
# 1         North America       Northwest

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "employees"
df_dim_employees = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_dim_employees.head(2)
# Out:
#    EmployeeID NationalIDNumber                 LoginID  ManagerID FirstName  \
# 0           1         14417807    adventure-works\guy1       16.0       Guy
# 1           2        253022876  adventure-works\kevin0        6.0     Kevin
#
#   MiddleName LastName                         Title  \
# 0          R  Gilbert  Production Technician - WC60
# 1          F    Brown           Marketing Assistant
#
#                  EmailAddress  EmailPromotion         Phone  \
# 0    guy1@adventure-works.com               0  320-555-0195
# 1  kevin0@adventure-works.com               2  150-555-0189
#
#              BirthDate MaritalStatus Gender             HireDate SalariedFlag  \
# 0  1972-05-15 00:00:00             M      M  1996-07-31 00:00:00            0
# 1  1977-06-03 00:00:00             S      M  1997-02-26 00:00:00            0
#
#    VacationHours  SickLeaveHours CurrentFlag
# 0             21              30           1
# 1             42              41           1

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "vendors"
df_dim_vendors = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_dim_vendors.head(2)
# Out:
#    VendorID AccountNumber                               Name  CreditRating  \
# 0         1  INTERNAT0001                      International             1
# 1         2  ELECTRON0002  Electronic Bike Repair & Supplies             1
#
#   PreferredVendorStatus ActiveFlag  AddressType        AddressLine1  \
# 0                     1          1  Main Office       683 Larch Ct.
# 1                     1          1  Main Office  8547 Catherine Way
#
#   AddressLine2            City StateProvinceCode State_Province PostalCode
# 0         None  Salt Lake City               UT            Utah      84101
# 1         None          Tacoma               WA      Washington      98403

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "products"
df_dim_products = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_dim_products.head(2)
# Out:
#    ProductID             Name ProductNumber MakeFlag FinishedGoodsFlag Color  \
# 0          1  Adjustable Race       AR-5381        0                 0  None
# 1          2     Bearing Ball       BA-8327        0                 0  None
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 0              1000           750           0.0        0.0  ...
# 1              1000           750           0.0        0.0  ...
#
#   DaysToManufacture ProductLine Class  Style  ProductCategory  \
# 0                 0        None  None   None             None
# 1                 0        None  None   None             None
#
#   ProductSubcategory ProductModel        SellStartDate SellEndDate  \
# 0               None         None  1998-06-01 00:00:00        None
# 1               None         None  1998-06-01 00:00:00        None
#
#   DiscontinuedDate
# 0             None
# 1             None
#
# [2 rows x 24 columns]

# %% [markdown]
# ## Transforming the Data Frames

# %%
sql_dim_date = "SELECT date_key, full_date FROM adventureworks.dim_date;"
df_dim_date = get_sql_dataframe(sql_dim_date, **mysql_args)
df_dim_date.full_date = df_dim_date.full_date.astype('datetime64[ns]').dt.date
df_dim_date.head(2)
# Out:
#    date_key   full_date
# 0  20000101  2000-01-01
# 1  20000102  2000-01-02

# %%
df_dim_customers.rename(columns={"id":"CustomerID"}, inplace=True)
df_dim_customers.insert(0, "customer_key", range(1, df_dim_customers.shape[0]+1))
df_dim_customers.head(2)
# Out:
#    customer_key  CustomerID AccountNumber CustomerType  AddressType  \
# 0             1           1    AW00000001            S  Main Office
# 1             2           2    AW00000002            S     Shipping
#
#          AddressLine1 AddressLine2     City StateProvinceCode State_Province  \
# 0  2251 Elliot Avenue         None  Seattle               WA      Washington
# 1     7943 Walnut Ave         None   Renton               WA      Washington
#
#   IsOnlyStateProvinceFlag PostalCode CountryRegionCode Country_Region  \
# 0                       0      98104                US  United States
# 1                       0      98055                US  United States
#
#   Sales Territory Group Sales Territory
# 0         North America       Northwest
# 1         North America       Northwest

# %%
df_dim_employees.rename(columns={"id":"EmployeeID"}, inplace=True)
df_dim_employees.insert(0, "employee_key", range(1, df_dim_employees.shape[0]+1))
df_dim_employees.HireDate = pd.to_datetime(df_dim_employees['HireDate']).dt.date
df_dim_employees.BirthDate = pd.to_datetime(df_dim_employees['BirthDate']).dt.date
df_dim_employees.head(2)
# Out:
#    employee_key  EmployeeID NationalIDNumber                 LoginID  \
# 0             1           1         14417807    adventure-works\guy1
# 1             2           2        253022876  adventure-works\kevin0
#
#    ManagerID FirstName MiddleName LastName                         Title  \
# 0       16.0       Guy          R  Gilbert  Production Technician - WC60
# 1        6.0     Kevin          F    Brown           Marketing Assistant
#
#                  EmailAddress  EmailPromotion         Phone   BirthDate  \
# 0    guy1@adventure-works.com               0  320-555-0195  1972-05-15
# 1  kevin0@adventure-works.com               2  150-555-0189  1977-06-03
#
#   MaritalStatus Gender    HireDate SalariedFlag  VacationHours  \
# 0             M      M  1996-07-31            0             21
# 1             S      M  1997-02-26            0             42
#
#    SickLeaveHours CurrentFlag
# 0              30           1
# 1              41           1

# %%
df_dim_vendors.rename(columns={"id":"VendorID"}, inplace=True)
df_dim_vendors.insert(0, "vendor_key", range(1, df_dim_vendors.shape[0]+1))
df_dim_vendors.head(2)
# Out:
#    vendor_key  VendorID AccountNumber                               Name  \
# 0           1         1  INTERNAT0001                      International
# 1           2         2  ELECTRON0002  Electronic Bike Repair & Supplies
#
#    CreditRating PreferredVendorStatus ActiveFlag  AddressType  \
# 0             1                     1          1  Main Office
# 1             1                     1          1  Main Office
#
#          AddressLine1 AddressLine2            City StateProvinceCode  \
# 0       683 Larch Ct.         None  Salt Lake City               UT
# 1  8547 Catherine Way         None          Tacoma               WA
#
#   State_Province PostalCode
# 0           Utah      84101
# 1     Washington      98403

# %%
df_dim_products.rename(columns={"id":"ProductID"}, inplace=True)
df_dim_products.insert(0, "product_key", range(1, df_dim_products.shape[0]+1))
df_dim_products.SellStartDate = pd.to_datetime(df_dim_products['SellStartDate']).dt.date
df_dim_products.drop(['SellEndDate'], axis=1, inplace=True) #all nulls
df_dim_products.drop(['DiscontinuedDate'], axis=1, inplace=True) #all nulls
df_dim_products.head(2)
# Out:
#    product_key  ProductID             Name ProductNumber MakeFlag  \
# 0            1          1  Adjustable Race       AR-5381        0
# 1            2          2     Bearing Ball       BA-8327        0
#
#   FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  ...  \
# 0                 0  None              1000           750           0.0  ...
# 1                 0  None              1000           750           0.0  ...
#
#    WeightUnitMeasureCode Weight DaysToManufacture ProductLine  Class  Style  \
# 0                   None    NaN                 0        None   None   None
# 1                   None    NaN                 0        None   None   None
#
#   ProductCategory ProductSubcategory ProductModel SellStartDate
# 0            None               None         None    1998-06-01
# 1            None               None         None    1998-06-01
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Loading the Transformed DataFrames into the New Data Warehouse; Validating Creation

# %%
dataframe = df_dim_customers
table_name = 'dim_customers'
primary_key = 'customer_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_dim_employees
table_name = 'dim_employees'
primary_key = 'employee_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_dim_vendors
table_name = 'dim_vendors'
primary_key = 'vendor_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_dim_products
table_name = 'dim_products'
primary_key = 'product_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
sql_dim_customers = "SELECT * FROM adventureworks.dim_customers;"
df_dim_customers = get_sql_dataframe(sql_dim_customers, **mysql_args)
df_dim_customers.head(2)
# Out:
#    customer_key  CustomerID AccountNumber CustomerType  AddressType  \
# 0             1           1    AW00000001            S  Main Office
# 1             2           2    AW00000002            S     Shipping
#
#          AddressLine1 AddressLine2     City StateProvinceCode State_Province  \
# 0  2251 Elliot Avenue         None  Seattle               WA      Washington
# 1     7943 Walnut Ave         None   Renton               WA      Washington
#
#   IsOnlyStateProvinceFlag PostalCode CountryRegionCode Country_Region  \
# 0                       0      98104                US  United States
# 1                       0      98055                US  United States
#
#   Sales Territory Group Sales Territory
# 0         North America       Northwest
# 1         North America       Northwest

# %%
sql_dim_employees = "SELECT * FROM adventureworks.dim_employees;"
df_dim_employees = get_sql_dataframe(sql_dim_employees, **mysql_args)
df_dim_employees.head(2)
# Out:
#    employee_key  EmployeeID NationalIDNumber                 LoginID  \
# 0             1           1         14417807    adventure-works\guy1
# 1             2           2        253022876  adventure-works\kevin0
#
#    ManagerID FirstName MiddleName LastName                         Title  \
# 0       16.0       Guy          R  Gilbert  Production Technician - WC60
# 1        6.0     Kevin          F    Brown           Marketing Assistant
#
#                  EmailAddress  EmailPromotion         Phone   BirthDate  \
# 0    guy1@adventure-works.com               0  320-555-0195  1972-05-15
# 1  kevin0@adventure-works.com               2  150-555-0189  1977-06-03
#
#   MaritalStatus Gender    HireDate SalariedFlag  VacationHours  \
# 0             M      M  1996-07-31            0             21
# 1             S      M  1997-02-26            0             42
#
#    SickLeaveHours CurrentFlag
# 0              30           1
# 1              41           1

# %%
sql_dim_vendors = "SELECT * FROM adventureworks.dim_vendors;"
df_dim_vendors = get_sql_dataframe(sql_dim_vendors, **mysql_args)
df_dim_vendors.head(2)
# Out:
#    vendor_key  VendorID AccountNumber                               Name  \
# 0           1         1  INTERNAT0001                      International
# 1           2         2  ELECTRON0002  Electronic Bike Repair & Supplies
#
#    CreditRating PreferredVendorStatus ActiveFlag  AddressType  \
# 0             1                     1          1  Main Office
# 1             1                     1          1  Main Office
#
#          AddressLine1 AddressLine2            City StateProvinceCode  \
# 0       683 Larch Ct.         None  Salt Lake City               UT
# 1  8547 Catherine Way         None          Tacoma               WA
#
#   State_Province PostalCode
# 0           Utah      84101
# 1     Washington      98403

# %%
sql_dim_products = "SELECT * FROM adventureworks.dim_products;"
df_dim_products = get_sql_dataframe(sql_dim_products, **mysql_args)
df_dim_products.head(2)
# Out:
#    product_key  ProductID             Name ProductNumber MakeFlag  \
# 0            1          1  Adjustable Race       AR-5381        0
# 1            2          2     Bearing Ball       BA-8327        0
#
#   FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  ...  \
# 0                 0  None              1000           750           0.0  ...
# 1                 0  None              1000           750           0.0  ...
#
#    WeightUnitMeasureCode Weight DaysToManufacture ProductLine  Class  Style  \
# 0                   None    NaN                 0        None   None   None
# 1                   None    NaN                 0        None   None   None
#
#   ProductCategory ProductSubcategory ProductModel SellStartDate
# 0            None               None         None    1998-06-01
# 1            None               None         None    1998-06-01
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Creating and Populating the New Fact Tables

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "fact_purchase_orders"
df_fact_purchase_orders = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  EmployeeID  VendorID  ProductID  \
# 0                1               0       4         244        83          1
# 1                2               0       1         231        32        360
#
#    OrderQty  UnitPrice  LineTotal            OrderDate  ... ShipRate  \
# 0         4    50.2600   201.0400  2001-05-17 00:00:00  ...     2.99
# 1         3    45.5805   136.7415  2001-05-17 00:00:00  ...     1.49
#
#               ShipDate  SubTotal   TaxAmt  Freight  TotalDue  \
# 0  2001-05-26 00:00:00  201.0400  16.0832   5.0260  222.1492
# 1  2001-05-26 00:00:00  272.1015  21.7681   6.8025  300.6721
#
#                DueDate  ReceivedQty RejectedQty  StockedQty
# 0  2001-05-31 00:00:00          3.0         0.0         3.0
# 1  2001-05-31 00:00:00          3.0         0.0         3.0
#
# [2 rows x 22 columns]

# %%
client = get_mongo_client(**mongodb_args)
query = {}
collection = "fact_sales_orders"
df_fact_sales_orders = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber            OrderDate              DueDate  \
# 0         43659               1  2001-07-01 00:00:00  2001-07-13 00:00:00
# 1         43659               1  2001-07-01 00:00:00  2001-07-13 00:00:00
#
#               ShipDate  Status OnlineOrderFlag SalesOrderNumber  \
# 0  2001-07-08 00:00:00       5               0          SO43659
# 1  2001-07-08 00:00:00       5               0          SO43659
#
#   PurchaseOrderNumber   AccountNumber  ...  CreditCardApprovalCode  \
# 0         PO522145787  10-4020-000676  ...           105041Vi84182
# 1         PO522145787  10-4020-000676  ...           105041Vi84182
#
#      SubTotal     TaxAmt   Freight    TotalDue  CarrierTrackingNumber  \
# 0  24643.9362  1971.5149  616.0984  27231.5495           4911-403C-98
# 1  24643.9362  1971.5149  616.0984  27231.5495           4911-403C-98
#
#    OrderQty ProductID  UnitPrice  LineTotal
# 0         4       711    20.1865     80.746
# 1         2       712     5.1865     10.373
#
# [2 rows x 34 columns]

# %%
sql_dim_date = "SELECT date_key, full_date FROM adventureworks.dim_date;"
df_dim_date = get_sql_dataframe(sql_dim_date, **mysql_args)
df_dim_date.full_date = df_dim_date.full_date.astype('datetime64[ns]').dt.date
df_dim_date.head(2)
# Out:
#    date_key   full_date
# 0  20000101  2000-01-01
# 1  20000102  2000-01-02

# %%
df_dim_sales_date = df_dim_date.rename(columns={"date_key" : "sales_order_date_key", "full_date" : "OrderDate"})
df_fact_sales_orders.OrderDate = df_fact_sales_orders.OrderDate.astype('datetime64[ns]').dt.date
df_fact_sales_orders = df_fact_sales_orders.merge(df_dim_sales_date, on='OrderDate', how='left')
df_fact_sales_orders.drop(['OrderDate'], axis=1, inplace=True)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber              DueDate             ShipDate  \
# 0         43659               1  2001-07-13 00:00:00  2001-07-08 00:00:00
# 1         43659               1  2001-07-13 00:00:00  2001-07-08 00:00:00
#
#    Status OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber  \
# 0       5               0          SO43659         PO522145787
# 1       5               0          SO43659         PO522145787
#
#     AccountNumber  CustomerID  ...    SubTotal     TaxAmt   Freight  \
# 0  10-4020-000676         676  ...  24643.9362  1971.5149  616.0984
# 1  10-4020-000676         676  ...  24643.9362  1971.5149  616.0984
#
#      TotalDue  CarrierTrackingNumber  OrderQty ProductID  UnitPrice  \
# 0  27231.5495           4911-403C-98         4       711    20.1865
# 1  27231.5495           4911-403C-98         2       712     5.1865
#
#    LineTotal sales_order_date_key
# 0     80.746             20010701
# 1     10.373             20010701
#
# [2 rows x 34 columns]

# %%
df_dim_ship_date = df_dim_date.rename(columns={"date_key" : "ship_date_key", "full_date" : "ShipDate"})
df_fact_sales_orders.ShipDate = df_fact_sales_orders.ShipDate.astype('datetime64[ns]').dt.date
df_fact_sales_orders = df_fact_sales_orders.merge(df_dim_ship_date, on='ShipDate', how='left')
df_fact_sales_orders.drop(['ShipDate'], axis=1, inplace=True)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber              DueDate  Status OnlineOrderFlag  \
# 0         43659               1  2001-07-13 00:00:00       5               0
# 1         43659               1  2001-07-13 00:00:00       5               0
#
#   SalesOrderNumber PurchaseOrderNumber   AccountNumber  CustomerID  ContactID  \
# 0          SO43659         PO522145787  10-4020-000676         676        378
# 1          SO43659         PO522145787  10-4020-000676         676        378
#
#    ...     TaxAmt   Freight    TotalDue  CarrierTrackingNumber  OrderQty  \
# 0  ...  1971.5149  616.0984  27231.5495           4911-403C-98         4
# 1  ...  1971.5149  616.0984  27231.5495           4911-403C-98         2
#
#   ProductID  UnitPrice  LineTotal sales_order_date_key ship_date_key
# 0       711    20.1865     80.746             20010701      20010708
# 1       712     5.1865     10.373             20010701      20010708
#
# [2 rows x 34 columns]

# %%
df_dim_due_date = df_dim_date.rename(columns={"date_key" : "due_date_key", "full_date" : "DueDate"})
df_fact_sales_orders.DueDate = df_fact_sales_orders.DueDate.astype('datetime64[ns]').dt.date
df_fact_sales_orders = df_fact_sales_orders.merge(df_dim_due_date, on='DueDate', how='left')
df_fact_sales_orders.drop(['DueDate'], axis=1, inplace=True)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber  Status OnlineOrderFlag SalesOrderNumber  \
# 0         43659               1       5               0          SO43659
# 1         43659               1       5               0          SO43659
#
#   PurchaseOrderNumber   AccountNumber  CustomerID  ContactID  SalesPersonID  \
# 0         PO522145787  10-4020-000676         676        378          279.0
# 1         PO522145787  10-4020-000676         676        378          279.0
#
#    ...   Freight    TotalDue  CarrierTrackingNumber  OrderQty ProductID  \
# 0  ...  616.0984  27231.5495           4911-403C-98         4       711
# 1  ...  616.0984  27231.5495           4911-403C-98         2       712
#
#    UnitPrice  LineTotal sales_order_date_key ship_date_key  due_date_key
# 0    20.1865     80.746             20010701      20010708      20010713
# 1     5.1865     10.373             20010701      20010708      20010713
#
# [2 rows x 34 columns]

# %%
df_dim_due_date = df_dim_date.rename(columns={"date_key" : "due_date_key", "full_date" : "DueDate"})
df_fact_purchase_orders.DueDate = df_fact_purchase_orders.DueDate.astype('datetime64[ns]').dt.date
df_fact_purchase_orders = df_fact_purchase_orders.merge(df_dim_due_date, on='DueDate', how='left')
df_fact_purchase_orders.drop(['DueDate'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  EmployeeID  VendorID  ProductID  \
# 0                1               0       4         244        83          1
# 1                2               0       1         231        32        360
#
#    OrderQty  UnitPrice  LineTotal            OrderDate  ... ShipRate  \
# 0         4    50.2600   201.0400  2001-05-17 00:00:00  ...     2.99
# 1         3    45.5805   136.7415  2001-05-17 00:00:00  ...     1.49
#
#               ShipDate  SubTotal   TaxAmt  Freight  TotalDue  ReceivedQty  \
# 0  2001-05-26 00:00:00  201.0400  16.0832   5.0260  222.1492          3.0
# 1  2001-05-26 00:00:00  272.1015  21.7681   6.8025  300.6721          3.0
#
#    RejectedQty  StockedQty  due_date_key
# 0          0.0         3.0      20010531
# 1          0.0         3.0      20010531
#
# [2 rows x 22 columns]

# %%
df_dim_ship_date = df_dim_date.rename(columns={"date_key" : "ship_date_key", "full_date" : "ShipDate"})
df_fact_purchase_orders.ShipDate = df_fact_purchase_orders.ShipDate.astype('datetime64[ns]').dt.date
df_fact_purchase_orders = df_fact_purchase_orders.merge(df_dim_ship_date, on='ShipDate', how='left')
df_fact_purchase_orders.drop(['ShipDate'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  EmployeeID  VendorID  ProductID  \
# 0                1               0       4         244        83          1
# 1                2               0       1         231        32        360
#
#    OrderQty  UnitPrice  LineTotal            OrderDate  ... ShipRate  \
# 0         4    50.2600   201.0400  2001-05-17 00:00:00  ...     2.99
# 1         3    45.5805   136.7415  2001-05-17 00:00:00  ...     1.49
#
#    SubTotal   TaxAmt  Freight  TotalDue  ReceivedQty  RejectedQty  StockedQty  \
# 0  201.0400  16.0832   5.0260  222.1492          3.0          0.0         3.0
# 1  272.1015  21.7681   6.8025  300.6721          3.0          0.0         3.0
#
#    due_date_key  ship_date_key
# 0      20010531       20010526
# 1      20010531       20010526
#
# [2 rows x 22 columns]

# %%
df_dim_purchase_date = df_dim_date.rename(columns={"date_key" : "purchase_date_key", "full_date" : "OrderDate"})
df_fact_purchase_orders.OrderDate = df_fact_purchase_orders.OrderDate.astype('datetime64[ns]').dt.date
df_fact_purchase_orders = df_fact_purchase_orders.merge(df_dim_purchase_date, on='OrderDate', how='left')
df_fact_purchase_orders.drop(['OrderDate'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  EmployeeID  VendorID  ProductID  \
# 0                1               0       4         244        83          1
# 1                2               0       1         231        32        360
#
#    OrderQty  UnitPrice  LineTotal         ShipMethod  ...  SubTotal   TaxAmt  \
# 0         4    50.2600   201.0400  OVERSEAS - DELUXE  ...  201.0400  16.0832
# 1         3    45.5805   136.7415  CARGO TRANSPORT 5  ...  272.1015  21.7681
#
#    Freight  TotalDue  ReceivedQty  RejectedQty  StockedQty  due_date_key  \
# 0   5.0260  222.1492          3.0          0.0         3.0      20010531
# 1   6.8025  300.6721          3.0          0.0         3.0      20010531
#
#    ship_date_key  purchase_date_key
# 0       20010526           20010517
# 1       20010526           20010517
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Looking up Primary Keys from the Dimension Tables

# %%
sql_dim_customers = "SELECT customer_key, CustomerID FROM adventureworks.dim_customers;"
df_dim_customers = get_sql_dataframe(sql_dim_customers, **mysql_args)
df_dim_customers.head(2)
# Out:
#    customer_key  CustomerID
# 0             1           1
# 1             2           2

# %%
sql_dim_employees = "SELECT employee_key, EmployeeID FROM adventureworks.dim_employees;"
df_dim_employees = get_sql_dataframe(sql_dim_employees, **mysql_args)
df_dim_employees.head(2)
# Out:
#    employee_key  EmployeeID
# 0             1           1
# 1             2           2

# %%
sql_dim_vendors = "SELECT vendor_key, VendorID FROM adventureworks.dim_vendors;"
df_dim_vendors = get_sql_dataframe(sql_dim_vendors, **mysql_args)
df_dim_vendors.head(2)
# Out:
#    vendor_key  VendorID
# 0           1         1
# 1           2         2

# %%
sql_dim_products = "SELECT product_key, ProductID FROM adventureworks.dim_products;"
df_dim_products = get_sql_dataframe(sql_dim_products, **mysql_args)
df_dim_products.head(2)
# Out:
#    product_key  ProductID
# 0            1          1
# 1            2          2

# %% [markdown]
# ## Looking up Corresponding Surrogate Primary Keys in the Dimension Tables

# %%
df_fact_purchase_orders = pd.merge(df_fact_purchase_orders, df_dim_employees[['EmployeeID', 'employee_key']], on = 'EmployeeID', how='inner')
df_fact_purchase_orders.drop(['EmployeeID'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  VendorID  ProductID  OrderQty  \
# 0                1               0       4        83          1         4
# 1                2               0       1        32        360         3
#
#    UnitPrice  LineTotal         ShipMethod  ShipBase  ...   TaxAmt  Freight  \
# 0    50.2600   201.0400  OVERSEAS - DELUXE     29.95  ...  16.0832   5.0260
# 1    45.5805   136.7415  CARGO TRANSPORT 5      8.99  ...  21.7681   6.8025
#
#    TotalDue  ReceivedQty  RejectedQty  StockedQty  due_date_key  \
# 0  222.1492          3.0          0.0         3.0      20010531
# 1  300.6721          3.0          0.0         3.0      20010531
#
#    ship_date_key  purchase_date_key  employee_key
# 0       20010526           20010517           244
# 1       20010526           20010517           231
#
# [2 rows x 22 columns]

# %%
df_fact_purchase_orders = pd.merge(df_fact_purchase_orders, df_dim_vendors[['VendorID', 'vendor_key']], on='VendorID', how='left')
df_fact_purchase_orders.drop(['VendorID'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    PurchaseOrderID  RevisionNumber  Status  ProductID  OrderQty  UnitPrice  \
# 0                1               0       4          1         4    50.2600
# 1                2               0       1        360         3    45.5805
#
#    LineTotal         ShipMethod  ShipBase  ShipRate  ...  Freight  TotalDue  \
# 0   201.0400  OVERSEAS - DELUXE     29.95      2.99  ...   5.0260  222.1492
# 1   136.7415  CARGO TRANSPORT 5      8.99      1.49  ...   6.8025  300.6721
#
#    ReceivedQty  RejectedQty  StockedQty  due_date_key  ship_date_key  \
# 0          3.0          0.0         3.0      20010531       20010526
# 1          3.0          0.0         3.0      20010531       20010526
#
#    purchase_date_key  employee_key  vendor_key
# 0           20010517           244          83
# 1           20010517           231          32
#
# [2 rows x 22 columns]

# %%
df_fact_purchase_orders.insert(0, 'fact_purchase_order_key', range(1, len(df_fact_purchase_orders) + 1))
df_fact_purchase_orders.head(2)
# Out:
#    fact_purchase_order_key  PurchaseOrderID  RevisionNumber  Status  \
# 0                        1                1               0       4
# 1                        2                2               0       1
#
#    ProductID  OrderQty  UnitPrice  LineTotal         ShipMethod  ShipBase  \
# 0          1         4    50.2600   201.0400  OVERSEAS - DELUXE     29.95
# 1        360         3    45.5805   136.7415  CARGO TRANSPORT 5      8.99
#
#    ...  Freight  TotalDue  ReceivedQty  RejectedQty  StockedQty  due_date_key  \
# 0  ...   5.0260  222.1492          3.0          0.0         3.0      20010531
# 1  ...   6.8025  300.6721          3.0          0.0         3.0      20010531
#
#    ship_date_key  purchase_date_key  employee_key  vendor_key
# 0       20010526           20010517           244          83
# 1       20010526           20010517           231          32
#
# [2 rows x 23 columns]

# %%
df_fact_purchase_orders = pd.merge(df_fact_purchase_orders, df_dim_products[['ProductID', 'product_key']], on='ProductID',how='left')
df_fact_purchase_orders.drop(['ProductID'], axis=1, inplace=True)
df_fact_purchase_orders.head(2)
# Out:
#    fact_purchase_order_key  PurchaseOrderID  RevisionNumber  Status  OrderQty  \
# 0                        1                1               0       4         4
# 1                        2                2               0       1         3
#
#    UnitPrice  LineTotal         ShipMethod  ShipBase  ShipRate  ...  TotalDue  \
# 0    50.2600   201.0400  OVERSEAS - DELUXE     29.95      2.99  ...  222.1492
# 1    45.5805   136.7415  CARGO TRANSPORT 5      8.99      1.49  ...  300.6721
#
#    ReceivedQty  RejectedQty  StockedQty  due_date_key  ship_date_key  \
# 0          3.0          0.0         3.0      20010531       20010526
# 1          3.0          0.0         3.0      20010531       20010526
#
#    purchase_date_key  employee_key  vendor_key  product_key
# 0           20010517           244          83            1
# 1           20010517           231          32           39
#
# [2 rows x 23 columns]

# %%
df_fact_sales_orders = pd.merge(df_fact_sales_orders, df_dim_customers[['CustomerID', 'customer_key']], on='CustomerID', how='left')
df_fact_sales_orders.drop(['CustomerID'], axis=1, inplace=True)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber  Status OnlineOrderFlag SalesOrderNumber  \
# 0         43659               1       5               0          SO43659
# 1         43659               1       5               0          SO43659
#
#   PurchaseOrderNumber   AccountNumber  ContactID  SalesPersonID  \
# 0         PO522145787  10-4020-000676        378          279.0
# 1         PO522145787  10-4020-000676        378          279.0
#
#   Sales Territory Group  ...    TotalDue  CarrierTrackingNumber  OrderQty  \
# 0         North America  ...  27231.5495           4911-403C-98         4
# 1         North America  ...  27231.5495           4911-403C-98         2
#
#   ProductID  UnitPrice  LineTotal sales_order_date_key ship_date_key  \
# 0       711    20.1865     80.746             20010701      20010708
# 1       712     5.1865     10.373             20010701      20010708
#
#    due_date_key  customer_key
# 0      20010713         687.0
# 1      20010713         687.0
#
# [2 rows x 34 columns]

# %%
df_fact_sales_orders = pd.merge(df_fact_sales_orders, df_dim_products[['ProductID', 'product_key']], on='ProductID',how='inner')
df_fact_sales_orders.drop(['ProductID'], axis=1, inplace=True)
df_fact_sales_orders.head(2)
# Out:
#    SalesOrderID  RevisionNumber  Status OnlineOrderFlag SalesOrderNumber  \
# 0         43659               1       5               0          SO43659
# 1         43659               1       5               0          SO43659
#
#   PurchaseOrderNumber   AccountNumber  ContactID  SalesPersonID  \
# 0         PO522145787  10-4020-000676        378          279.0
# 1         PO522145787  10-4020-000676        378          279.0
#
#   Sales Territory Group  ...    TotalDue  CarrierTrackingNumber  OrderQty  \
# 0         North America  ...  27231.5495           4911-403C-98         4
# 1         North America  ...  27231.5495           4911-403C-98         2
#
#   UnitPrice  LineTotal  sales_order_date_key ship_date_key due_date_key  \
# 0   20.1865     80.746              20010701      20010708     20010713
# 1    5.1865     10.373              20010701      20010708     20010713
#
#    customer_key  product_key
# 0         687.0          216
# 1         687.0          217
#
# [2 rows x 34 columns]

# %%
df_fact_sales_orders.insert(0, 'fact_sales_orders_key', range(1, len(df_fact_sales_orders) + 1))
df_fact_sales_orders.head(2)
# Out:
#    fact_sales_orders_key  SalesOrderID  RevisionNumber  Status  \
# 0                      1         43659               1       5
# 1                      2         43659               1       5
#
#   OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0               0          SO43659         PO522145787  10-4020-000676
# 1               0          SO43659         PO522145787  10-4020-000676
#
#    ContactID  SalesPersonID  ...    TotalDue CarrierTrackingNumber  OrderQty  \
# 0        378          279.0  ...  27231.5495          4911-403C-98         4
# 1        378          279.0  ...  27231.5495          4911-403C-98         2
#
#    UnitPrice LineTotal  sales_order_date_key  ship_date_key due_date_key  \
# 0    20.1865    80.746              20010701       20010708     20010713
# 1     5.1865    10.373              20010701       20010708     20010713
#
#   customer_key  product_key
# 0        687.0          216
# 1        687.0          217
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Loading Newly Transformed MongoDB Date into the AdventureWorks Data Warehouse

# %%
dataframe = df_fact_sales_orders
table_name = 'fact_sales_orders'
primary_key = 'fact_sales_orders_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_fact_purchase_orders
table_name = 'fact_purchase_orders'
primary_key = 'fact_purchase_order_key'
db_operation = 'insert'

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %% [markdown]
# ## Demonstrating the New Data Warehouse Exists and Contains Correct Data

# %%
sql_employee_find = """
    SELECT 
        e.FirstName AS first_name,
        e.LastName AS last_name,
        e.Title AS job_title,
        SUM(e.SickLeaveHours) AS sick_leave_hours
        from adventureworks.dim_employees AS e
    GROUP BY e.employee_key
    ORDER BY e.LastName
"""

# %%
df_fact_employee_find = get_sql_dataframe(sql_employee_find, **mysql_args)
df_fact_employee_find.head(10)
# Out:
#   first_name    last_name                          job_title  sick_leave_hours
# 0       Syed        Abbas              Pacific Sales Manager              30.0
# 1        Kim  Abercrombie       Production Technician - WC60              32.0
# 2      Hazem     Abolrous          Quality Assurance Manager              60.0
# 3      Pilar     Ackerman  Shipping and Receiving Supervisor              66.0
# 4        Jay        Adams       Production Technician - WC60              36.0
# 5   François     Ajenstat             Database Administrator              53.0
# 6        Amy      Alberts             European Sales Manager              30.0
# 7       Greg     Alderson       Production Technician - WC45              62.0
# 8       Sean    Alexander       Quality Assurance Technician              61.0
# 9       Gary       Altman                 Facilities Manager              63.0

# %%
sql_fact_purchase_orders = """
    SELECT 
        p.Name AS product_name,
        COUNT(f.PurchaseOrderID) AS total_transactions,
        SUM(f.OrderQty) AS total_quantity
    FROM adventureworks.dim_products AS p
    JOIN adventureworks.fact_purchase_orders AS f
        ON f.product_key = p.product_key
    GROUP BY p.product_key, p.Name
    ORDER BY p.product_key;
"""

# %%
df_fact_purchase_orders = get_sql_dataframe(sql_fact_purchase_orders, **mysql_args)
df_fact_purchase_orders
# Out:
#               product_name  total_transactions  total_quantity
# 0          Adjustable Race                   7            22.0
# 1             Bearing Ball                   6            18.0
# 2    Headset Ball Bearings                   7            21.0
# 3              LL Crankarm                   9          4950.0
# 4              ML Crankarm                   9          4950.0
# ..                     ...                 ...             ...
# 206          ML Road Pedal                   9          4950.0
# 207          HL Road Pedal                   5          2750.0
# 208          Touring Pedal                   7          3850.0
# 209           Front Brakes                   5          2750.0
# 210                  Chain                   6           360.0
#
# [211 rows x 3 columns]

# %%
sql_fact_sales_orders = """
    SELECT 
        c.AccountNumber AS account_number,
        COUNT(s.SalesOrderID) AS total_transactions,
        MAX(s.SubTotal) AS total_price
    FROM adventureworks.dim_customers AS c
    JOIN adventureworks.fact_sales_orders AS s
        ON s.customer_key = c.customer_key
    GROUP BY c.customer_key, c.AccountNumber
    ORDER BY c.customer_key;
"""

# %%
df_fact_sales_orders = get_sql_dataframe(sql_fact_sales_orders, **mysql_args)
df_fact_sales_orders.head(10)
# Out:
#   account_number  total_transactions  total_price
# 0     AW00000001                  12   13216.0537
# 1     AW00000011                   6   31625.9064
# 2     AW00000017                   5   17040.8246
# 3     AW00000018                  10   39677.4848
# 4     AW00000022                   1     503.3507
# 5     AW00000027                   8   47343.2903
# 6     AW00000029                   9   39078.9348
# 7     AW00000036                  13   16463.3400
# 8     AW00000073                  10   24713.9540
# 9     AW00000078                  28   49671.5619
